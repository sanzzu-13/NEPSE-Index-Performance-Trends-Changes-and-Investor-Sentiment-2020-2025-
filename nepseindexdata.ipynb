# %% [markdown]
#
#  # NEPSE Index Performance: Trends, Changes, and Investor Sentiment (2020–2025)

# %% [markdown]
# <img src="https://i1.wp.com/kaamkura.com/wp-content/uploads/2021/06/Nepse-Chart.png?resize=768%2C502&ssl=1" alt="NEPSE Chart" width="400"/>

# %% [markdown]
# # About the Dataset
# ## NEPSE Daily Index Data (2020-2025)
#
# This dataset contains daily records of the Nepal Stock Exchange (NEPSE) Index from January 1, 2020, to March 4, 2025. The NEPSE Index reflects the overall performance of Nepal’s stock market by tracking the value of listed companies.
#
# ---
#
# ## What’s in the Dataset?
# - **Date:** The trading day (e.g., 2025-03-04).
# - **Index Value:** The closing value of the NEPSE Index for that day.
# - **Absolute Change:** How much the index changed from the previous day (in points).
# - **Percentage Change:** The daily percentage change (how much the index went up or down).
#
# ---
#
# ## Data Details
# - Covers over 5 years of daily trading data (excludes weekends and holidays).
# - Contains around 1,200 to 1,500 rows of data.
# - Data sourced from ShareSansar, a popular Nepal financial website.
# - Collected and cleaned using automated Python tools.
#
# ---
#
# <!-- ## How Can You Use This Data?
# - Analyze trends in Nepal’s stock market.
# - Forecast future index values with models like ARIMA or LSTM.
# - Study market growth and volatility.
# - Create charts and graphs to visualize daily changes.
# - Learn financial data analysis using real market data. -->

# %% [markdown]
# ## Source of Data
# Dataset retrieved from [Kaggle](https://www.kaggle.com/datasets/suyogghimire/nepse-daily-index-data-2020-2025).

# %% [markdown]
# ## 🎯 Objective of Analyzing NEPSE Data:
# ### 1. Identify trend (upward/downward)
# ### 2. Track Daily Market Performance

# %%
import pandas as pd
import numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Import the libraries needed for data analysis

# %%
df=pd.read_csv(r"C:\Users\D E L L\Data With mala\Data with sanjaya\data analysis in clz\nepse_daily_data.csv")

# %%
df.head()
# Out:
#          Date  Index Value  Absolute Change  Percentage Change
# 0  2020-01-01      1169.50             3.47               0.30
# 1  2020-01-02      1166.21            -3.29              -0.28
# 2  2020-01-05      1182.31            16.10               1.38
# 3  2020-01-06      1200.69            18.38               1.55
# 4  2020-01-07      1216.92            16.23               1.35

# %% [markdown]
# - There are only 4 attributes: Date, Index Value, Absolute Change, and Percentage Change.

# %%
df.shape
# Out:
# (1164, 4)

# %% [markdown]
# - There are only 1,164 rows and 4 attributes in this dataset.

# %%
df.describe()
# Out:
#        Index Value  Absolute Change  Percentage Change
# count  1164.000000      1164.000000        1164.000000
# mean   2202.263677         1.437869           0.088290
# std     458.195072        34.272081           1.551739
# min    1166.210000      -145.050000          -6.040000
# 25%    1931.507500       -17.017500          -0.802500
# 50%    2088.430000        -0.180000          -0.005000
# 75%    2630.995000        16.437500           0.800000
# max    3198.600000       161.940000           6.060000

# %% [markdown]
# - The mean of the Index Value is 2202.26.
#
# - The mean of the Absolute Change is 1.44.
#
# - The mean of the Percentage Change is 0.09%.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1164 entries, 0 to 1163
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1164 non-null   object
#  1   Index Value        1164 non-null   float64
#  2   Absolute Change    1164 non-null   float64
#  3   Percentage Change  1164 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 36.5+ KB

# %% [markdown]
# - There are no null values in the dataset.
#
# - The dataset contains only object and float data types.
#
# - Memory usage is approximately 35.5 KB.

# %%
# Load your dataset
df = pd.read_csv("nepse_daily_data.csv")

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the date as the index for time series plotting
df.set_index('Date', inplace=True)

# Plot the Index Value over time
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['Index Value'], color='blue', linewidth=1)
plt.title('NEPSE Index Value Over Time')
plt.xlabel('Date')
plt.ylabel('Index Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📌 Why Use a Histogram
# - A histogram is used to show the distribution of data.
#
# - Understand how frequently values occur
#
# - Identify the shape of the data (e.g., skewed or normal)
#
# - Detect outliers and data spread
#
# - Make patterns in the data easy to see
#
# #
# - In 2020, the value of NEPSE was below 1250.
#
# - The value of NEPSE gradually increased until the middle of 2021.
#
# - In 2022, the value of NEPSE decreased compared to the previous year.
#
# - At the beginning of 2022, the NEPSE value rose again but then declined afterward.
#
# - In the middle of 2022, the market became volatile, fluctuating between 1750 and 2000 until mid-2024.
#
# - In mid-2024, the NEPSE market rose again, reaching a value of 3000.
#
# - In 2025, the market remains between 2750 and 3000.

# %%
# Load your dataset
df = pd.read_csv("nepse_daily_data.csv")

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the date as the index for time series plotting
df.set_index('Date', inplace=True)

# Plot the Absolute Change over time
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['Absolute Change'], color='orange', linewidth=1)
plt.title('NEPSE Absolute Change Over Time')
plt.xlabel('Date')
plt.ylabel('Absolute Change')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - int this We can see a NEPSE Absolute change
# - The NEPSE market was less volatile in early 2020, gained momentum in 2021, became highly volatile in 2022, and then settled into a more stable but still active phase from 2023 to 2025.
#
# - The spikes in the chart reflect investor sentiment shifts, possibly due to macroeconomic or political events.

# %%
# Load your dataset
df = pd.read_csv("nepse_daily_data.csv")

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the date as the index for time series plotting
df.set_index('Date', inplace=True)

# Plot the Percentage Change over time
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['Percentage Change'], color='purple', linewidth=1)
plt.title('NEPSE Percentage Change Over Time')
plt.xlabel('Date')
plt.ylabel('Percentage Change (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - This graph displays the daily percentage change of the NEPSE (Nepal Stock Exchange) index.
# - It covers a time frame from early 2020 to early 2025.
# - Each point on the line indicates the increase or decrease (in percentage) of the NEPSE's value for that specific day.
# - Over the five years, daily market changes mostly hovered around zero, lacking any sustained positive or negative trend.

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create a box plot for Index Value
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Index Value'], color='skyblue')
plt.title('Box Plot of NEPSE Index Value')
plt.xlabel('Index Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Why Use a Box Plot?
# A box plot  is used to summarize the distribution of a dataset. It helps to:
#
# - show the median, minimum, and maximum values
#
# - Display the spread and variability of the data
#
# - Identify outliers (unusual values)
#
# - Compare distributions between variables or over time
# ##
# - The vertical line inside the light blue box shows the median (middle value) of the NEPSE Index, which is around 2000–2050.
# - The light blue box stretches from about 1900 to 2550, covering the middle 50% of all NEPSE Index values.
# - The "whiskers" (lines extending from the box) show the full spread of values (excluding outliers), ranging from about 1200 to 3200.
# - There are no dots or points outside the whiskers, meaning there are no extreme values
# - The median is slightly to the left, and the right whisker is a bit longer, showing a slight skew toward higher values, but the distribution is mostly balanced.

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create a box plot for Absolute Change
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Absolute Change'], color='orange')
plt.title('Box Plot of NEPSE Absolute Change')
plt.xlabel('Absolute Change')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Shows daily point changes in NEPSE (not percentages).
#
# - Median (middle line) is near zero, meaning most daily changes are small.
#
# - Middle 50% of changes (orange box) range from -15 to +15 points.
#
# - Whiskers stretch from about -70 to +70 points, covering most changes.
#
# - Diamonds outside whiskers are outliers—rare big changes up to ±150 points.
#
# - The plot is fairly balanced, showing large ups and downs happen equally.

# %%
# Create a pair plot
sns.pairplot(df[['Index Value', 'Absolute Change', 'Percentage Change']], diag_kind='kde')
plt.suptitle('Pair Plot for NEPSE Data', y=1.02)
plt.show()

# %% [markdown]
# - Each scatter plot shows how two variables relate (correlation, trend, clusters, etc.).
# - These show the distribution of individual variables.
# - Useful to spot groups, trends, or outliers in data.
# - Easy way to compare multiple variables at once.
# - Helps decide which variables are related or important.
# ##
# * Scatter Plots (Off-diagonal):
#
# - Index Value vs Absolute Change: No clear pattern. Daily changes vary, whether index is high or low.
#
# - Index Value vs Percentage Change: Also no trend. Index level doesn’t predict % change.
#
# - Absolute vs Percentage Change: Strong positive linear trend. Higher point change = higher % change.
#
# * Distributions (Diagonal):
#
# - Index Value: Bimodal (two peaks) → Market spent time in two main value ranges.
#
# - Absolute Change: Sharp peak around 0 → Most changes are small but some big movements exist.
#
# - Percentage Change: Similar to Absolute Change → Mostly small daily % changes, fairly symmetric.
#
# * Patterns & Insights:
#
# - Clusters: Found in Index Value (two main groups).
#
# - Trends: Strong trend only between Absolute & Percentage Change.
#
# - Outliers: None extreme in scatter plots; some spread seen in distributions.
#
# * Conclusion:
#
# - Absolute Change" and "Percentage Change" are strongly related.
#
# - Index Value" doesn’t explain how much the market moves daily.

# %%
# Compute the correlation matrix
correlation_matrix = df[['Index Value', 'Absolute Change', 'Percentage Change']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix for NEPSE Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# # NEPSE Correlation Matrix
#
# - Correlation values range from -1 to +1:
# * +1 = perfect positive relation, -1 = perfect negative, 0 = no relation.
#
# - Each variable is perfectly correlated with itself (value = 1).
#
# - Index Value and Absolute Change: Correlation is almost zero (0.02). This means the current index level doesn’t predict the size of daily point changes.
#
# - Index Value and Percentage Change: Correlation is zero (0.00). So, the index level doesn’t predict daily percent changes either.
#
# - Absolute Change and Percentage Change: Very strong positive correlation (0.97). When point changes are big, percentage changes are big too, and vice versa.

# %% [markdown]
# # 📊 Final Findings: NEPSE Index Analysis (2020–2025)
#
# ## 📉 Trend Identification (Upward/Downward Movement)
# - **2020:** NEPSE was relatively low, staying below 1250.
# - **2021:** A strong upward trend was observed, with values steadily increasing.
# - **2022:** The index saw a decline, followed by a brief recovery early in the year, then continued falling.
# - **Mid-2022 to 2024:** Market became volatile, fluctuating between 1750 and 2000.
# - **Mid-2024:** The index rose again, reaching a peak of around 3000.
# - **2025:** NEPSE shows signs of stabilization, staying mostly between 2750 and 3000.
#
# ## 📅📉 Daily Market Performance
# - Daily percentage and absolute changes mostly hovered near zero, showing no long-term bias toward increase or decrease.
# - Median of daily point change is close to zero → most changes are small.
# - Outliers exist, with a few extreme changes (±150 points), reflecting possible macroeconomic or political impacts.
# - Box plot shows a central index value of ~2000–2050 with no extreme outliers, indicating moderate stability.
# - The distribution is slightly right-skewed, meaning occasional higher values, but generally balanced.
# ---
#
# <sub>Made by Sanjaaya Kumar Giri</sub>
